# %%
# import pandas as pd
# import json
# import numpy
# import os
# from pathlib import Path
# from datetime import date, timedelta
# import urllib.parse
# import time
# import requests

# # https://docs.slack.dev/tools/python-slack-sdk
# from slack_sdk.webhook import WebhookClient
# from slack_sdk.errors import SlackApiError


# # the URL we'll send slack alerts to
# SLACK_WEBHOOK = "https://hooks.slack.com/services/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"

# # the slack API only allows sending 50 block elements at a time
# MAX_SLACK_BLOCKS = 50

# def send_message(content, webhook):  # send message to webhook
#     message = {"text": content}
#     message_json = json.dumps(message)
#     return requests.post(webhook, message_json)

# send_message("Hello!",SLACK_WEBHOOK)
# Out:
# <Response [200]>

# %%
import pandas as pd
import json
import numpy
import os
from pathlib import Path
from datetime import date, timedelta
import urllib.parse
import time
import requests

# https://docs.slack.dev/tools/python-slack-sdk
from slack_sdk.webhook import WebhookClient
from slack_sdk.errors import SlackApiError


# the URL we'll send slack alerts to
SLACK_WEBHOOK = SLACK_WEBHOOK_HEATBOT

# the slack API only allows sending 50 block elements at a time
MAX_SLACK_BLOCKS = 50

def send_message(content, webhook):  # send message to webhook
    message = {"text": content}
    message_json = json.dumps(message)
    return requests.post(webhook, message_json)

send_message("slayyyyy!",SLACK_WEBHOOK)
# Out:
# <Response [200]>

# %%
test_df = pd.read_csv('./data/test/all_mod1.csv')
test_df2 = pd.read_csv('./data/test/all_mod2.csv')

# %%
def splitdate(df):
    df[['inc_date','inc_time']] = df['incident_date'].str.split('T', expand=True)
    df[['dth_date', 'dth_time']] = df['death_date'].str.split('T', expand=True)

splitdate(test_df)
test_df
# Out:
#     Unnamed: 0    casenumber            incident_date  \
# 0            0  ME2016-03171  2016-06-27T15:24:00.000
# 1            1  ME2017-04963  2017-10-22T04:56:00.000
# 2            2  ME2017-04962  2017-10-22T08:50:00.000
# 3            3  ME2019-02763  2019-06-17T15:00:00.000
# 4            4  ME2015-03061  2015-07-19T01:00:00.000
# 5            5  ME2018-03047  2018-06-30T09:33:00.000
# 6            6  ME2018-03654  2018-08-04T12:45:00.000
# 7            7  ME2016-03895  2016-08-10T11:26:00.000
# 8            8  ME2015-03222  2015-07-28T19:37:00.000
# 9            9  ME2015-01578  2015-04-17T19:45:00.000
# 10          10  ME2015-03060  2015-07-19T01:40:00.000
# 11          11  ME2016-03517  2016-07-19T14:06:00.000
# 12          12  ME2018-02328  2018-05-16T17:25:00.000
# 13          13  ME2018-03034  2018-06-29T16:10:00.000
# 14          14  ME2019-03094  2019-07-05T10:30:00.000
# 15          15  ME2019-03360  2019-07-20T14:49:00.000
# 16          16  ME2019-03279  2019-05-05T11:30:00.000
# 17          17  ME2019-03366  2019-07-20T21:25:00.000
# 18          18  ME2019-03372  2019-07-19T16:55:00.000
# 19          19  ME2019-05081  2019-10-28T11:02:00.000
# 20          20  ME2019-05731  2019-12-03T09:00:00.000
# 21          21  ME2020-01244  2020-03-06T20:50:00.000
HYPERTENSIVE AND ATHEROSCLEROTIC CARDIOVASCULA...  ...
# 12  ENVIRONMENTAL HEAT EXPOSURE . MALFUNCTION OF A...  ...
# 13                   ETHANOL AND AMPHETAMINE TOXICITY  ...
# 14                     ORGANIC CARDIOVASCULAR DISEASE  ...
# 15                           CORONARY ATHEROSCLEROSIS  ...
# 16  HYPERTENSIVE AND ATHEROSCLEROTIC CARDIOVASCULA...  ...
# 17  HYPERTENSIVE-ARTERIOSCLEROTIC CARDIOVASCULAR D...  ...
# 18         COMPLICATIONS OF HYPERTHERMIA. HEAT STROKE  ...
# 19  HYPERTENSIVE AND ATHEROSCLEROTIC CARDIOVASCULA...  ...
# 20  ENVIRONMENTAL HEAT EXPOSURE. MALFUNCTION OF RE...  ...
# 21           ATHEROSCLEROTIC CORONARY ARTERY DISEASE.  ...
# 22  COMPLICATIONS OF HYPERTHERMIA. COMBINATION OF ...  ...
# 23                                        HEAT STROKE  ...
# 24                        HYPERTHERMIA. HEAT EXPOSURE  ...
# 25                                        HEAT STROKE  ...
# 26  ENVIRONMENTAL HEAT EXPOSURE. FURNACE MALFUNCTI...  ...
# 27               HYPERTHERMIA. FURNACE MALFUNCTIONING  ...
# 28                       COMPLICATIONS OF HEAT STROKE  ...
# 29             FENTANYL AND PROBABLE COCAINE TOXICITY  ...
# 30  ENVIRONMENTAL HEAT EXPOSURE. HOT RESIDENTIAL B...  ...
# 31  ENVIRONMENTAL HEAT EXPOSURE. HOT RESIDENTIAL B...  ...
# 32  ENVIRONMENTAL HEAT EXPOSURE . HOT RESIDENTIAL ...  ...
# 33          HYPERTHERMIA. ENVIRONMENTAL HEAT EXPOSURE  ...
# 34                            CORONARY ARTERY DISEASE  ...
# 35                                 CHRONIC ETHANOLISM  ...
# 36  ENVIRONMENTAL HEAT EXPOSURE. HOT APARTMENT UNI...  ...
# 37  HYPERTENSIVE ARTERIOSCLEROTIC CARDIOVASCULAR D...  ...
# 38             ATHEROSCLEROTIC CARDIOVASCULAR DISEASE  ...
# 39  COMBINED DRUG (COCAINE, FENTANYL, AND 4-ANPP (...  ...
# 40                       COMPLICATIONS OF HEAT STROKE  ...
# 41  HYPERTENSIVE ARTERIOSCLEROTIC CARDIOVASCULAR D...  ...
# 42              FENTANYL AND DIPHENHYDRAMINE TOXICITY  ...
# 43                        HYPERTROPHIC CARDIOMYOPATHY  ...
# 44  ENVIRONMENTAL HEAT EXPOSURE . PROLONGED CONTAC...  ...
# 45                                        HEAT STROKE  ...
# 46                             ACUTE ETHANOL TOXICITY  ...
# 47  HYPERTENSIVE ARTERIOSCLEROTIC CARDIOVASCULAR D...  ...
# 48  MYOCARDIAL INFARCTION. HYPERTENSIVE-ARTERIOSCL...  ...
# 49                     ORGANIC CARDIOVASCULAR DISEASE  ...
# 50  HYPERTHERMIA. ENVIRONMENTAL HEAT EXPOSURE IN T...  ...
#
#           chi_commarea covid_related                 :id  \
# 0             ROSELAND         False  row-cjgt_crd7-xyuy
# 1                  NaN         False  row-anqg-rrnp-nc7f
# 2                  NaN         False  row-zkkj-326b.5nki
# 3                  NaN         False  row-bdwb~ncpq_653d
# 4                  NaN         False  row-u2wg.si6s.22un
# 5            WEST TOWN         False  row-4s8n~kc2j-xr4s
# 6       NORTH LAWNDALE         False  row-qnfn_9dzi.ryh2
# 7              PULLMAN         False  row-89ey~272e.kmpt
# 8          ALBANY PARK         False  row-cv5x_vpkg_t5y2
# 9   WASHINGTON HEIGHTS         False  row-69nx_tzpf~gwgh
# 10              AUSTIN         False  row-rpfe.upfy-6i43
# 11              AUSTIN         False  row-abf4~55am.fuim
# 12             ASHBURN         False  row-aabb~uneg-iqw7
# 13        LINCOLN PARK         False  row-a6w7~azdj_7tzw
# 14        LOGAN SQUARE         False  row-2dcz.ifbk-2qam
# 15      LINCOLN SQUARE         False  row-dr7b-ndbe~kyum
# 16           LAKE VIEW         False  row-6efr-yfxa-pdtz
# 17  EAST GARFIELD PARK         False  row-rbn4_2svs-xuwe
# 18        LOGAN SQUARE         False  row-38rh~sugb_i5qr
# 19             CHATHAM         False  row-e459.j7py_pccy
# 20             ASHBURN         False  row-2ftk_xts3~5sgs
# 21           LAKE VIEW         False  row-aqg3.ijzh.7jwp
# 22       HUMBOLDT PARK         False  row-q6a4.pcf7.xazw
# 23                 NaN         False  row-u5ws.w6f2.qc62
# 24           MONTCLARE         False  row-scpq.6bea-dukr
# 25                 NaN         False  row-arry-74j3.gxt2
# 26                 NaN         False  row-w66d-t2az_pjtj
# 27                 NaN         False  row-zqq5.hk2v~z3xq
# 28             DOUGLAS         False  row-b8ms~7syy~iujg
# 29           WEST TOWN         False  row-gbc9~2a3j~yy5u
# 30         ROGERS PARK         False  row-mbkp-2h3w~2zy7
# 31         ROGERS PARK         False  row-h4xy_wi5x.iby5
# 32         ROGERS PARK         False  row-xj7q-kgue.dscz
# 33     NEAR SOUTH SIDE         False  row-yxda_7uj4~5rhc
# 34                 NaN         False  row-79cm_2ksd-b9p8
# 35            AVONDALE         False  row-ujup-mp7e-tbj4
# 36      WEST ENGLEWOOD         False  row-2km4_wjfk~u6m5
# 37            WOODLAWN         False  row-rvat_dsh4_48ia
# 38                 NaN         False  row-fy3a_8yc9~xm8f
# 39      WEST ENGLEWOOD         False  row-fuen.gn2q.thep
# 40                 NaN         False  row-vsbi.8xr4.v98v
# 41      AUBURN GRESHAM         False  row-kktx~vqbs_jehn
# 42                 NaN         False  row-qad3~nzzr-qcup
# 43              AUSTIN         False  row-3tdg-vit8.j6e2
# 44                 NaN         False  row-uy6e.kxrx_uv5v
# 45                 NaN         False  row-qgn6-88u2-djxv
# 46           GAGE PARK         False  row-9tkf_2seb~gppz
# 47        NORWOOD PARK         False  row-vgr8~txzr.i4h8
# 48               OHARE         False  row-tqk4-dc8y.z2g6
# 49                 NaN         False  row-qr98-f75u.wfvp
# 50        CHICAGO LAWN         False  row-rzej~pb48-7b4c
#
#                  :created_at               :updated_at  \
# 0   2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 1   2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 2   2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 3   2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 4   2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 5   2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 6   2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 7   2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 8   2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 9   2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 10  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 11  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 12  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 13  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 14  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 15  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 16  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 17  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 18  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 19  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 20  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 21  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 22  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 23  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 24  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 25  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 26  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 27  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 28  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 29  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 30  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 31  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 32  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 33  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 34  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 35  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 36  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 37  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 38  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 39  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 40  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 41  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 42  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 43  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 44  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 45  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 46  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 47  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 48  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 49  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 50  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 8   19:37:00.000  2015-07-28  20:39:00.000
# 9   19:45:00.000  2015-04-17  20:51:00.000
# 10  01:40:00.000  2015-07-19  02:02:00.000
# 11  14:06:00.000  2016-07-19  14:46:00.000
# 12  17:25:00.000  2018-05-16  18:10:00.000
# 13  16:10:00.000  2018-06-29  16:20:00.000
# 14  10:30:00.000  2019-07-05  11:00:00.000
# 15  14:49:00.000  2019-07-20  15:41:00.000
# 16  11:30:00.000  2019-07-15  11:24:00.000
# 17  21:25:00.000  2019-07-20  21:50:00.000
# 18  16:55:00.000  2019-07-21  06:23:00.000
# 19  11:02:00.000  2019-10-28  11:45:00.000
# 20  09:00:00.000  2019-12-03  09:49:00.000
# 21  20:50:00.000  2020-03-06  21:33:00.000
# 22  14:51:00.000  2020-06-27  00:59:00.000
# 23  20:56:00.000  2020-06-27  22:04:00.000
# 24  16:57:00.000  2020-07-02  15:25:00.000
# 25  12:30:00.000  2020-07-09  13:00:00.000
# 26  14:10:00.000  2020-10-04  14:27:00.000
# 27  14:10:00.000  2020-10-04  18:49:00.000
# 28  00:00:00.000  2021-07-17  06:34:00.000
# 29  17:16:00.000  2021-07-24  22:18:00.000
# 30  14:00:00.000  2022-05-14  14:39:00.000
# 31  19:00:00.000  2022-05-14  19:04:00.000
# 32  11:10:00.000  2022-05-14  11:32:00.000
# 33  18:33:00.000  2022-06-14  19:18:00.000
# 34  00:00:00.000  2022-06-25  21:16:00.000
# 35  08:15:00.000  2022-08-11  08:30:00.000
# 36  09:45:00.000  2022-11-24  09:55:00.000
# 37  19:12:00.000  2023-05-20  10:41:00.000
# 38  15:05:00.000  2023-06-30  13:38:00.000
# 39  11:15:00.000  2023-08-11  10:54:00.000
# 40  12:18:00.000  2024-04-30  11:30:00.000
# 41  12:23:00.000  2024-06-18  10:29:00.000
# 42  16:33:00.000  2024-07-23  16:22:00.000
# 43  00:43:00.000  2024-08-28  00:27:00.000
# 44  15:26:00.000  2024-12-21  13:35:00.000
# 45  19:55:00.000  2025-05-15  17:46:00.000
# 46  18:50:00.000  2025-06-24  16:25:00.000
# 47  15:30:00.000  2025-06-26  14:37:00.000
# 48  18:53:00.000  2025-07-07  18:02:00.000
# 49  13:09:00.000  2026-07-01  12:32:00.000
# 50  23:33:00.000  2026-07-01  20:31:00.000
#
# [51 rows x 38 columns]

# %%
display(test_df)
# Out:
# None

# %%
test_df[['inc_date', 'inc_time']] = test_df['incident_date'].str.split('T', expand=True)
test_df[['inc_date', 'inc_time']] = test_df['incident_date'].str.split('T', expand=True)
test_df[['dth_date', 'dth_time']] = test_df['death_date'].str.split('T', expand=True)
test_df[['dth_date', 'dth_time']] = test_df['death_date'].str.split('T', expand=True)

test_df2[['inc_date', 'inc_time']] = test_df2['incident_date'].str.split('T', expand=True)
test_df2[['inc_date', 'inc_time']] = test_df2['incident_date'].str.split('T', expand=True)
test_df2[['dth_date', 'dth_time']] = test_df2['death_date'].str.split('T', expand=True)
test_df2[['dth_date', 'dth_time']] = test_df2['death_date'].str.split('T', expand=True)

# %%
agency = "datacatalog.cookcountyil.gov"
dataset = "cjeq-bs86" # this is the shortlink!
stringlink = f'https://{agency}/d/{dataset}'
gitlink = "https://github.com/cam-rodriguez/cpm_heatbot/tree/a207489e7adb54302c4755b1a0c7349fbddd6413/data"

# %%
# slack link formatting
# <https://docs.slack.dev/|This message is a link>

# %%
def textgenerator(df1, df2):
    length = len(df2) - len(df1)

    if length == 0:
        txt = f"*No new data* was added to the dataset between the last scrape and this one. \n <{stringlink}|Click here> to view the data portal, and <{gitlink}|here> to view the most recent copy."

    elif length == 1:
        txt = f"*One new row* was added to the dataset between the last scrape and this one. \n <{stringlink}|Click here> to view the data portal, and <{gitlink}|here> to view the most recent copy. <!channel>"

    elif length > 1:
        txt = f"*{length} new rows* were added to the dataset between the last scrape and this one. \n <{stringlink}|Click here> to view the data portal, and <{gitlink}|here> to view the most recent copy. <!channel>"

    else:
        txt = f"Error of some kind..."
    
    return txt

# %%
newrows = test_df2[~test_df2.isin(test_df)] # where rows in the new dataframe aren't in the older dataframe
newrows = newrows[~newrows['casenumber'].isna()] # where case number is not null...
# newrows = newrows.dropna()
newrows # print new rows
# Out:
#     Unnamed: 0    casenumber            incident_date  \
# 51        51.0  ME2026-03491  2026-07-02T15:57:00.000
# 52        52.0  ME2026-03506  2026-07-03T10:18:00.000
# 53        53.0  ME2026-03513  2026-07-03T17:48:00.000
# 54        54.0  ME2026-03523  2026-07-02T12:50:00.000
# 55        55.0  ME2026-03638  2026-06-29T00:00:00.000
# 56        56.0  ME2026-03649  2026-06-29T10:00:00.000
# 57        57.0  ME2026-03743  2026-07-14T11:27:00.000
#
#                  death_date   age  gender   race latino    manner  \
# 51  2026-07-02T15:32:00.000  48.0    Male  Black  False  ACCIDENT
# 52  2026-07-03T10:01:00.000  57.0    Male  White   True   NATURAL
# 53  2026-07-03T17:25:00.000  71.0  Female  Black  False   NATURAL
# 54  2026-07-04T12:15:00.000  44.0    Male  White   True  ACCIDENT
# 55  2026-07-09T15:52:00.000  45.0  Female  White   True  ACCIDENT
# 56  2026-07-10T02:07:00.000  77.0    Male  White  False  ACCIDENT
# 57  2026-07-14T10:51:00.000  65.0    Male  White  False   NATURAL
#
#                                          primarycause  ... residence_city  \
# 51                                        HEAT STROKE  ...        Chicago
# 52  HYPERTENSIVE AND ATHEROSCLEROTIC CARDIOVASCULA...  ...        Chicago
# 53                HYPERTENSIVE CARDIOVASCULAR DISEASE  ...        Chicago
# 54                                        HEAT STROKE  ...        Chicago
# 55                       COMPLICATIONS OF HEAT STROKE  ...        Chicago
# 56                           COMPLICATIONS OF FALL(S)  ...    Westchester
# 57                     ORGANIC CARDIOVASCULAR DISEASE  ...       Oak Lawn
#
#    residence_zip objectid chi_ward        chi_commarea covid_related  \
# 51       60612.0  97283.0     28.0  EAST GARFIELD PARK         False
# 52       60608.0  97297.0     12.0       MCKINLEY PARK         False
# 53       60621.0  97304.0     16.0           ENGLEWOOD         False
# 54       60629.0  97311.0     15.0        CHICAGO LAWN         False
# 55       60619.0  97432.0     20.0            NEW CITY         False
# 56       60154.0  97441.0      NaN                 NaN         False
# 57       60453.0  97541.0      NaN                 NaN         False
#
#                    :id               :created_at               :updated_at  \
# 51  row-4agc.n45x.zqvw  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 52  row-8b9p.nu4n~5fcf  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 53  row-mt4y_zt3v_skr2  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 54  row-j46t-672f_76u9  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 55  row-y2ii_8nfn-x5yk  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 56  row-jfra-wevt~r7nj  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 57  row-r52t~k593-98rx  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
#
#    primarycause_lineb
# 51                NaN
# 52                NaN
# 53                NaN
# 54                NaN
# 55                NaN
# 56                NaN
# 57                NaN
#
# [7 rows x 34 columns]

# %%
newrows['casenumber']
# Out:
# 51    ME2026-03491
# 52    ME2026-03506
# 53    ME2026-03513
# 54    ME2026-03523
# 55    ME2026-03638
# 56    ME2026-03649
# 57    ME2026-03743
# Name: casenumber, dtype: str

# %%
test_df.head(2)
# Out:
#    Unnamed: 0    casenumber            incident_date               death_date  \
# 0           0  ME2016-03171  2016-06-27T15:24:00.000  2016-06-27T16:36:00.000
# 1           1  ME2017-04963  2017-10-22T04:56:00.000  2017-10-22T05:55:00.000
#
#    age  gender   race  latino    manner  \
# 0   83  Female  Black   False   NATURAL
# 1   61    Male  Black   False  ACCIDENT
#
#                                         primarycause  ... residence_city  \
# 0  HYPERTENSIVE ARTERIOSCLEROTIC CARDIOVASCULAR D...  ...        Chicago
# 1  HYPERTHERMIA. EXPOSURE TO HIGH ENVIRONMENTAL T...  ...   Richton Park
#
#   residence_zip  objectid  chi_ward  chi_commarea  covid_related  \
# 0         60629      2739       9.0      ROSELAND          False
# 1         60471      4762       NaN           NaN          False
#
#                   :id               :created_at               :updated_at  \
# 0  row-cjgt_crd7-xyuy  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 1  row-anqg-rrnp-nc7f  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
#
#                            primarycause_lineb
# 0                                         NaN
# 1  EXPOSURE TO HIGH ENVIRONMENTAL TEMPERATURE
#
# [2 rows x 34 columns]

# %%
textgenerator(test_df, test_df2)
# Out:
# '*7 new rows* were added to the dataset between the last scrape and this one.'

# %%
send_message("slayyyyy!",SLACK_WEBHOOK) # send message to heatbot channel/webhook of choice
# Out:
# <Response [200]>

# %%
from datetime import datetime, timedelta
rightnow = datetime.now().strftime('%A %B %d %I:%M %p')

# %%
print(rightnow)
# Out:
# Tuesday August 04 03:37 PM

# %%
placeholder = "Heat deaths"

# %%
text = textgenerator(test_df, test_df2)
formatted = f'❗️ *{placeholder} update, {rightnow}* \n {text}'
send_message(formatted, SLACK_WEBHOOK)
# Out:
# <Response [200]>

# %%
def diffgenerator(test_df, test_df2):
    if len(test_df) <

# %%
if len(test_df) < len(test_df2):
    numdiff = len(test_df2) - len(test_df)
    newrows = test_df2[~test_df2.isin(test_df)]
    casenums = newrows['casenumber']


    txt = f"New update: {numdiff} new rows were added to the dataset."
    updtxt = f"New update: {numdiff} new heat death was recorded."

# %%
test_df2['casenumber'].equals(test_df['casenumber'])
# Out:
# False

# %%
newrows.columns
# Out:
# Index(['Unnamed: 0', 'casenumber', 'incident_date', 'death_date', 'age',
#        'gender', 'race', 'latino', 'manner', 'primarycause',
#        'primarycause_linea', 'secondarycause', 'gunrelated', 'opioids',
#        'cold_related', 'heat_related', 'transportation_related',
#        'commissioner_district', 'incident_street', 'incident_city',
#        'incident_zip', 'longitude', 'latitude', 'location', 'residence_city',
#        'residence_zip', 'objectid', 'chi_ward', 'chi_commarea',
#        'covid_related', ':id', ':created_at', ':updated_at',
#        'primarycause_lineb'],
#       dtype='str')

# %%
test_df.columns
# Out:
# Index(['Unnamed: 0', 'casenumber', 'incident_date', 'death_date', 'age',
#        'gender', 'race', 'latino', 'manner', 'primarycause',
#        'primarycause_linea', 'secondarycause', 'gunrelated', 'opioids',
#        'cold_related', 'heat_related', 'transportation_related',
#        'commissioner_district', 'incident_street', 'incident_city',
#        'incident_zip', 'longitude', 'latitude', 'location', 'residence_city',
#        'residence_zip', 'objectid', 'chi_ward', 'chi_commarea',
#        'covid_related', ':id', ':created_at', ':updated_at',
#        'primarycause_lineb', 'inc_date', 'inc_time', 'dth_date', 'dth_time'],
#       dtype='str')

# %%
test_df['inc_loc'] = test_df['incident_street'].str.upper() + ', ' + test_df['incident_city'] + ', IL'
test_df
# Out:
#     Unnamed: 0    casenumber            incident_date  \
# 0            0  ME2016-03171  2016-06-27T15:24:00.000
# 1            1  ME2017-04963  2017-10-22T04:56:00.000
# 2            2  ME2017-04962  2017-10-22T08:50:00.000
# 3            3  ME2019-02763  2019-06-17T15:00:00.000
# 4            4  ME2015-03061  2015-07-19T01:00:00.000
# 5            5  ME2018-03047  2018-06-30T09:33:00.000
# 6            6  ME2018-03654  2018-08-04T12:45:00.000
# 7            7  ME2016-03895  2016-08-10T11:26:00.000
# 8            8  ME2015-03222  2015-07-28T19:37:00.000
# 9            9  ME2015-01578  2015-04-17T19:45:00.000
# 10          10  ME2015-03060  2015-07-19T01:40:00.000
# 11          11  ME2016-03517  2016-07-19T14:06:00.000
# 12          12  ME2018-02328  2018-05-16T17:25:00.000
# 13          13  ME2018-03034  2018-06-29T16:10:00.000
# 14          14  ME2019-03094  2019-07-05T10:30:00.000
# 15          15  ME2019-03360  2019-07-20T14:49:00.000
# 16          16  ME2019-03279  2019-05-05T11:30:00.000
# 17          17  ME2019-03366  2019-07-20T21:25:00.000
# 18          18  ME2019-03372  2019-07-19T16:55:00.000
# 19          19  ME2019-05081  2019-10-28T11:02:00.000
# 20          20  ME2019-05731  2019-12-03T09:00:00.000
# 21          21  ME2020-01244  2020-03-06T20:50:00.000
# 22          22  ME2020-08242  2020-06-25T14:51:00.000
# 23          23  ME2020-08357  2020-06-27T20:56:00.000
# 24          24  ME2020-08539  2020-07-01T16:57:00.000
# 25          25  ME2020-08771  2020-07-09T12:30:00.000
# 26          26  ME2020-11109  2020-10-04T14:10:00.000
# 27          27  ME2020-11117  2020-10-04T14:10:00.000
# 28          28  ME2021-06815  2021-07-04T00:00:00.000
# 29          29  ME2021-07018  2021-07-24T17:16:00.000
# 30          30  ME2022-05305  2022-05-14T14:00:00.000
ARTERIOSCLEROTIC CARDIOVASCULAR D...  ...         False
# 18         COMPLICATIONS OF HYPERTHERMIA. HEAT STROKE  ...         False
# 19  HYPERTENSIVE AND ATHEROSCLEROTIC CARDIOVASCULA...  ...         False
# 20  ENVIRONMENTAL HEAT EXPOSURE. MALFUNCTION OF RE...  ...         False
# 21           ATHEROSCLEROTIC CORONARY ARTERY DISEASE.  ...         False
# 22  COMPLICATIONS OF HYPERTHERMIA. COMBINATION OF ...  ...         False
# 23                                        HEAT STROKE  ...         False
# 24                        HYPERTHERMIA. HEAT EXPOSURE  ...         False
# 25                                        HEAT STROKE  ...         False
# 26  ENVIRONMENTAL HEAT EXPOSURE. FURNACE MALFUNCTI...  ...         False
# 27               HYPERTHERMIA. FURNACE MALFUNCTIONING  ...         False
# 28                       COMPLICATIONS OF HEAT STROKE  ...         False
# 29             FENTANYL AND PROBABLE COCAINE TOXICITY  ...         False
# 30  ENVIRONMENTAL HEAT EXPOSURE. HOT RESIDENTIAL B...  ...         False
# 31  ENVIRONMENTAL HEAT EXPOSURE. HOT RESIDENTIAL B...  ...         False
# 32  ENVIRONMENTAL HEAT EXPOSURE . HOT RESIDENTIAL ...  ...         False
# 33          HYPERTHERMIA. ENVIRONMENTAL HEAT EXPOSURE  ...         False
# 34                            CORONARY ARTERY DISEASE  ...         False
# 35                                 CHRONIC ETHANOLISM  ...         False
# 36  ENVIRONMENTAL HEAT EXPOSURE. HOT APARTMENT UNI...  ...         False
# 37  HYPERTENSIVE ARTERIOSCLEROTIC CARDIOVASCULAR D...  ...         False
# 38             ATHEROSCLEROTIC CARDIOVASCULAR DISEASE  ...         False
# 39  COMBINED DRUG (COCAINE, FENTANYL, AND 4-ANPP (...  ...         False
# 40                       COMPLICATIONS OF HEAT STROKE  ...         False
# 41  HYPERTENSIVE ARTERIOSCLEROTIC CARDIOVASCULAR D...  ...         False
# 42              FENTANYL AND DIPHENHYDRAMINE TOXICITY  ...         False
# 43                        HYPERTROPHIC CARDIOMYOPATHY  ...         False
# 44  ENVIRONMENTAL HEAT EXPOSURE . PROLONGED CONTAC...  ...         False
# 45                                        HEAT STROKE  ...         False
# 46                             ACUTE ETHANOL TOXICITY  ...         False
# 47  HYPERTENSIVE ARTERIOSCLEROTIC CARDIOVASCULAR D...  ...         False
# 48  MYOCARDIAL INFARCTION. HYPERTENSIVE-ARTERIOSCL...  ...         False
# 49                     ORGANIC CARDIOVASCULAR DISEASE  ...         False
# 50  HYPERTHERMIA. ENVIRONMENTAL HEAT EXPOSURE IN T...  ...         False
#
#                    :id               :created_at               :updated_at  \
# 0   row-cjgt_crd7-xyuy  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 1   row-anqg-rrnp-nc7f  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 2   row-zkkj-326b.5nki  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 3   row-bdwb~ncpq_653d  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 4   row-u2wg.si6s.22un  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 5   row-4s8n~kc2j-xr4s  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 6   row-qnfn_9dzi.ryh2  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 7   row-89ey~272e.kmpt  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 8   row-cv5x_vpkg_t5y2  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 9   row-69nx_tzpf~gwgh  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 10  row-rpfe.upfy-6i43  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 11  row-abf4~55am.fuim  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 12  row-aabb~uneg-iqw7  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 13  row-a6w7~azdj_7tzw  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 14  row-2dcz.ifbk-2qam  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 15  row-dr7b-ndbe~kyum  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 16  row-6efr-yfxa-pdtz  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 17  row-rbn4_2svs-xuwe  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 18  row-38rh~sugb_i5qr  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 19  row-e459.j7py_pccy  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 20  row-2ftk_xts3~5sgs  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 21  row-aqg3.ijzh.7jwp  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 22  row-q6a4.pcf7.xazw  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 23  row-u5ws.w6f2.qc62  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 24  row-scpq.6bea-dukr  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 25  row-arry-74j3.gxt2  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 26  row-w66d-t2az_pjtj  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 27  row-zqq5.hk2v~z3xq  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 28  row-b8ms~7syy~iujg  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 29  row-gbc9~2a3j~yy5u  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 30  row-mbkp-2h3w~2zy7  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 31  row-h4xy_wi5x.iby5  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 32  row-xj7q-kgue.dscz  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 33  row-yxda_7uj4~5rhc  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 34  row-79cm_2ksd-b9p8  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 35  row-ujup-mp7e-tbj4  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 36  row-2km4_wjfk~u6m5  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 37  row-rvat_dsh4_48ia  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 38  row-fy3a_8yc9~xm8f  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 39  row-fuen.gn2q.thep  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 40  row-vsbi.8xr4.v98v  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 41  row-kktx~vqbs_jehn  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 42  row-qad3~nzzr-qcup  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 43  row-3tdg-vit8.j6e2  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 44  row-uy6e.kxrx_uv5v  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 45  row-qgn6-88u2-djxv  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 46  row-9tkf_2seb~gppz  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 47  row-vgr8~txzr.i4h8  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 48  row-tqk4-dc8y.z2g6  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 49  row-qr98-f75u.wfvp  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
# 50  row-rzej~pb48-7b4c  2026-08-01T20:53:17.197Z  2026-08-01T20:53:17.197Z
#
#                                    primarycause_lineb    inc_date  \
# 0                                                 NaN  2016-06-27
# 1          EXPOSURE TO HIGH ENVIRONMENTAL TEMPERATURE  2017-10-22
# 2          EXPOSURE TO HIGH ENVIRONMENTAL TEMPERATURE  2017-10-22
# 3   FAULTY MODIFICATION OF HOME FURNACE AND THERMO...  2019-06-17
# 4                                                 NaN  2015-07-19
# 5                                                 NaN  2018-06-30
# 6                                                 NaN  2018-08-04
# 7                                                 NaN  2016-08-10
# 8                                                 NaN  2015-07-28
# 9                                                 NaN  2015-04-17
# 10                                                NaN  2015-07-19
# 11                                                NaN  2016-07-19
# 12            MALFUNCTION OF A RESIDENTIAL THERMOSTAT  2018-05-16
# 13                                                NaN  2018-06-29
# 14                                                NaN  2019-07-05
# 15                                                NaN  2019-07-20
# 16                                                NaN  2019-05-05
# 17                                                NaN  2019-07-20
# 18                                        HEAT STROKE  2019-07-19
# 19                                                NaN  2019-10-28
# 20          MALFUNCTION OF RESIDENTIAL HEATING SYSTEM  2019-12-03
# 21                                                NaN  2020-03-06
# 22  COMBINATION OF ENVIRONMENT AND FENTANYL AND CA...  2020-06-25
# 23                                                NaN  2020-06-27
# 24                                      HEAT EXPOSURE  2020-07-01
# 25                                                NaN  2020-07-09
# 26                             FURNACE MALFUNCTIONING  2020-10-04
# 27                             FURNACE MALFUNCTIONING  2020-10-04
# 28                                                NaN  2021-07-04
# 29                                                NaN  2021-07-24
# 30  HOT RESIDENTIAL BUILDING DURING HEAT-RELATED W...  2022-05-14
# 31  HOT RESIDENTIAL BUILDING DURING HEAT-RELATED W...  2022-05-14
# 37                   6330 S STONY ISLAND, CHICAGO, IL
# 38              1062 COPPERFIELD LANE, SCHAUMBURG, IL
# 39                  1420 W. MARQUETTE RD, CHICAGO, IL
# 40                        5400 W 87TH ST, BURBANK, IL
# 41        8531 S. BISHOP ST BASEMENT APT, CHICAGO, IL
# 42                       3800 CICERO AVE., CICERO, IL
# 43               7 S MAYFIELD AVENUE#107, CHICAGO, IL
# 44                     19 TIMBER LANE, NORTHBROOK, IL
# 45                 7615 ROOSEVELT RD, FOREST PARK, IL
# 46                      3135 W. 53RD ST., CHICAGO, IL
# 47               6901 W. HIGGINS UNIT 3W, CHICAGO, IL
# 48                     1000 W O'HARE AVE, CHICAGO, IL
# 49                    1210 DARROW APT 2, EVANSTON, IL
# 50     W 63RD STREET & S CAMPBELL AVENUE, CHICAGO, IL
#
# [51 rows x 39 columns]

# %%
import tabulate

# %%
test_df2 = test_df

# %%
# if the new scrape DOES NOT EQUAL the last scrape...

if test_df2.equals(test_df) != 'True': # in this case, it'll be the newest scrape against the penultimate scrape
    # get the row difference
    numdiff = len(test_df2) - len(test_df) 

    # drop nonmatching rows (and yes, there's probably a better way to do this)
    newrows = test_df2[~test_df2.isin(test_df)] 
    newrows = newrows[~newrows['casenumber'].isna()]

    # generating things for text
    caselist = newrows['casenumber']
    
    # data table
    # data cleaning that could literally be done anywhere else but for some reason i'm doing it here ugh
    newrows['age'] = newrows['age'].astype('str')
    newrows['age'] = newrows['age'].str.replace('.0','',regex=True)

    newrows['latino'] = newrows['latino'].astype('str')
    newrows['latino'] = newrows['latino'].str.replace('False','',regex=True)
    newrows['latino'] = newrows['latino'].str.replace('True','Latino',regex=True)

    newrows['incident_zip'] = newrows['incident_zip'].astype('str')
    newrows['incident_zip'] = newrows['incident_zip'].str.replace('.0','',regex=False)


    newrows['inc_loc'] = newrows['incident_street'].str.upper() + ', ' + newrows['incident_city'] + ', IL ' + newrows['incident_zip']
    newrows['inc_loc'] = newrows['inc_loc'].str.title()


    newrows['maploc'] = newrows['inc_loc'].str.replace(' ','+',regex=True)
    gmaps_start = "https://google.com/maps/place/"
    newrows['gmaps_link'] = "<" + gmaps_start + newrows['maploc'] + "/ | here >"

    # newrows['gmaps_link'] = f'<{gmaps_start}/{maploc}/ | >'

    # concatenate to get a big string
    newrows_trunc = newrows[['casenumber','inc_date','dth_date','age', 'incident_city', 'gender','race','latino','primarycause','secondarycause','inc_loc','chi_ward','chi_commarea','residence_city','gmaps_link']]
    
    # make it a string list
    newrows_trunc['stringy'] = "• *Case number " + newrows_trunc['casenumber'] + "* — a " + newrows_trunc['age'] + "-year-old " + newrows_trunc['latino'] + " " + newrows_trunc['race'] + " " + newrows_trunc['gender'].str.lower() + " in " + newrows_trunc['incident_city'].str.title() + ". \n The determined cause of death is " + newrows_trunc['primarycause'] + " and " + newrows_trunc['secondarycause'] + ". The death date was *" + newrows_trunc['dth_date'] + "* and the incident that led to their death was on *" + newrows_trunc['inc_date'] + "* at " + newrows_trunc['inc_loc'] + ". 📍 view incident location " + newrows_trunc['gmaps_link'] + ". \n"
    stringy_list = newrows_trunc['stringy']

    ########
    # send leading message about the update with the diff#

    text = textgenerator(test_df, test_df2)
    formatted = f'❗️ *{placeholder} update — {rightnow}* \n {text} \n'
    send_message(formatted, SLACK_WEBHOOK)

    # send the details about each row in the diff #
    # for every new row in the new data, send a message with that row's contents
    for item in list(stringy_list):

        # dataformat = f'The updated data rows are below: \n {list}'
        send_message(item, SLACK_WEBHOOK)

# %%
print(newdata)
# Out:
# |    | casenumber   | inc_date   | dth_date   | gender   | race   | latino   | primarycause                                            | secondarycause                                                                                  | inc_loc                                        |   chi_ward | chi_commarea       | residence_city   |
# |---:|:-------------|:-----------|:-----------|:---------|:-------|:---------|:--------------------------------------------------------|:------------------------------------------------------------------------------------------------|:-----------------------------------------------|-----------:|:-------------------|:-----------------|
# | 51 | ME2026-03491 | 2026-07-02 | 2026-07-02 | Male     | Black  |          | HEAT STROKE                                             | ETHANOL INTOXICATION                                                                            | 2916 W. POLK AVE, CHICAGO, IL 612              |         28 | EAST GARFIELD PARK | Chicago          |
# | 52 | ME2026-03506 | 2026-07-03 | 2026-07-03 | Male     | White  | Latino   | HYPERTENSIVE AND ATHEROSCLEROTIC CARDIOVASCULAR DISEASE | DIABETES MELLITUS; HEAT STRESS                                                                  | 3288 S ARCHER AVE UNIT 2, CHICAGO, IL 8        |         12 | MCKINLEY PARK      | Chicago          |
# | 53 | ME2026-03513 | 2026-07-03 | 2026-07-03 | Female   | Black  |          | HYPERTENSIVE CARDIOVASCULAR DISEASE                     | ASTHMA, OBESITY, HEAT STRESS                                                                    | 1016 W 70TH ST APT 1E, CHICAGO, IL 621         |         16 | ENGLEWOOD          | Chicago          |
# | 54 | ME2026-03523 | 2026-07-02 | 2026-07-04 | Male     | White  | Latino   | HEAT STROKE                                             | HYPERTENSION, DIABETES MELLITUS, OBESITY                                                        | 6318 S. MOZART, CHICAGO, IL 629                |         15 | CHICAGO LAWN       | Chicago          |
# | 55 | ME2026-03638 | 2026-06-29 | 2026-07-09 | Female   | White  | Latino   | COMPLICATIONS OF HEAT STROKE                            | SCHIZOPHRENIA                                                                                   | W 53RD AND S HALSTEAD, CHICAGO, IL 9           |         20 | NEW CITY           | Chicago          |
# | 56 | ME2026-03649 | 2026-06-29 | 2026-07-10 | Male     | White  |          | COMPLICATIONS OF FALL(S)                                | DYSPHAGIA, CHRONIC ETHANOLISM, PAROXYSMAL ATRIAL FLUTTER/TACHYCARDIA, OSTEOPOROSIS, HEAT STRESS | 1944 GARDNER ROAD, WESTCHESTER, IL 154         |        nan | nan                | Westchester      |
# | 57 | ME2026-03743 | 2026-07-14 | 2026-07-14 | Male     | White  |          | ORGANIC CARDIOVASCULAR DISEASE                          | HEAT STRESS DUE TO ENVIRONMENTAL HYPERTHERMIA                                                   | 9001 S CICERO AVE TRAILER 92, OAK LAWN, IL 453 |        nan | nan                | Oak Lawn         |

# %%
$
